# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)

# %%
x = np.random.normal(0, 1, 500)
y = np.random.normal(0, 1, 500)

X = np.vstack((x, y)).T

# %%
plt.scatter(X[:, 0], X[:, 1])
plt.title('Generated Data')
plt.axis('equal');

# %%
X.shape
# Out:
# (500, 2)

# %%
X[0]
# Out:
# array([0.0650712 , 1.51616913])

# %%
np.dot(X, X.T)
# Out:
# array([[ 2.3030031 ,  0.93155699, -0.01577857, ...,  1.31530708,
#         -1.95007372, -0.25799592],
#        [ 0.93155699,  0.54847212,  0.27766141, ...,  0.60134323,
#         -0.08097038,  0.11242249],
#        [-0.01577857,  0.27766141,  0.47011079, ...,  0.10566787,
#          1.18459189,  0.36047157],
#        ...,
#        [ 1.31530708,  0.60134323,  0.10566787, ...,  0.77918877,
#         -0.8279622 , -0.05982558],
#        [-1.95007372, -0.08097038,  1.18459189, ..., -0.8279622 ,
#          4.56990015,  1.11233728],
#        [-0.25799592,  0.11242249,  0.36047157, ..., -0.05982558,
#          1.11233728,  0.3026635 ]])

# %%
def cov(x, y):
    xbar, ybar = x.mean(), y.mean()
    return np.sum((x-xbar)*(y-ybar))/(len(x) - 1)

def cov_matrix(X):
    return np.array([[cov(X[0], X[0]), cov(X[0], X[1])], [cov(X[1], X[0]), cov(X[1], X[1])]])

cov_matrix(X)
# Out:
# array([[1.05284261, 0.73909345],
#        [0.73909345, 0.51884215]])

# %%
X = X - np.mean(X, 0)

sx, sy = 0.7, 3.4

scale = np.array([[sx, 0], [0, sy]])
Y = X.dot(scale)

plt.scatter(Y[:, 0], Y[:, 1])
plt.title('Transformed Data')
plt.axis('equal')

cov_matrix(Y.T)
# Out:
# array([[ 0.4854029 , -0.03497625],
#        [-0.03497625, 10.94136216]])

# %%
theta = 0.77*np.pi
c, s = np.cos(theta), np.sin(theta)
rot = np.array([[c, -s], [s, c]])

T = scale.dot(rot)
Y = X.dot(T)

plt.scatter(Y[:, 0], Y[:, 1])
plt.title('Transformed Data')
plt.axis('equal')

cov_matrix(Y.T)
# Out:
# array([[ 5.09284339, -5.19113913],
#        [-5.19113913,  6.33392167]])
